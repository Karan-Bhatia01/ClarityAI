# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("test.csv")

# %%
df.isnull().sum().to_dict()
# Out:
# {'show_id': 0,
#  'type': 0,
#  'title': 0,
#  'director': 2634,
#  'cast': 825,
#  'country': 831,
#  'date_added': 10,
#  'release_year': 0,
#  'rating': 4,
#  'duration': 3,
#  'listed_in': 0,
#  'description': 0}
